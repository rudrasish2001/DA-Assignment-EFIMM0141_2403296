# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
Q1=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2017_Q1.csv")
Q1['Quarter']='Q1'
Q2=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2017_Q2.csv")
Q2['Quarter']='Q2'
Q3=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2017_Q3.csv")
Q3['Quarter']='Q3'
Q4=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2017_Q4.csv")
Q4['Quarter']='Q4'

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
Y1 = pd.concat([Q1,Q2,Q3,Q4], ignore_index=True)

# %%
Y1.dtypes
# Out:
# trip_id                int64
# start_time            object
# end_time              object
# bikeid                 int64
# tripduration           int64
# from_station_id        int64
# from_station_name     object
# to_station_id          int64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# Quarter               object
# dtype: object

# %%
Q5=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2018_Q1.csv")
Q5['Quarter']='Q5'
Q6=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2018_Q2.csv")
Q6['Quarter']='Q6'
Q7=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2018_Q3.csv")
Q7['Quarter']='Q7'
Q8=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2018_Q4.csv")
Q8['Quarter']='Q8'

# %%
Y2 = pd.concat([Q5,Q6,Q7,Q8], ignore_index=True)

# %%
Y2.drop(['01 - Rental Details Rental ID','01 - Rental Details Local Start Time','01 - Rental Details Local End Time','01 - Rental Details Bike ID','01 - Rental Details Duration In Seconds Uncapped','03 - Rental Start Station ID','03 - Rental Start Station Name','02 - Rental End Station ID','02 - Rental End Station Name','05 - Member Details Member Birthday Year','User Type','Member Gender'], axis=1, inplace=True)

# %%
Y2.dtypes
# Out:
# Quarter               object
# trip_id              float64
# start_time            object
# end_time              object
# bikeid               float64
# tripduration          object
# from_station_id      float64
# from_station_name     object
# to_station_id        float64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# dtype: object

# %%
Q9=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2019_Q1.csv")
Q9['Quarter']='Q9'
Q10=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2019_Q2.csv")
Q10['Quarter']='Q10'
Q11=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2019_Q3.csv")
Q11['Quarter']='Q11'
Q12=pd.read_csv("/content/drive/MyDrive/DA ASSIGNMENT/DATA/Divvy_Trips_2019_Q4.csv")
Q12['Quarter']='Q12'

# %%
Y3 = pd.concat([Q9,Q10,Q11,Q12], ignore_index=True)

# %%
Y3.drop(['01 - Rental Details Rental ID','01 - Rental Details Local Start Time','01 - Rental Details Local End Time','01 - Rental Details Bike ID','01 - Rental Details Duration In Seconds Uncapped','03 - Rental Start Station ID','03 - Rental Start Station Name','02 - Rental End Station ID','02 - Rental End Station Name','05 - Member Details Member Birthday Year','User Type','Member Gender'], axis=1, inplace=True)

# %%
Y3.dtypes
# Out:
# trip_id              float64
# start_time            object
# end_time              object
# bikeid               float64
# tripduration          object
# from_station_id      float64
# from_station_name     object
# to_station_id        float64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# Quarter               object
# dtype: object

# %%
ALL_DF=pd.concat([Y1,Y2,Y3], ignore_index=True)

# %%
ALL_DF.dtypes
# Out:
# trip_id              float64
# start_time            object
# end_time              object
# bikeid               float64
# tripduration          object
# from_station_id      float64
# from_station_name     object
# to_station_id        float64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# Quarter               object
# dtype: object

# %%
ALL_DF.to_csv('/content/drive/MyDrive/DA ASSIGNMENT/DATA/divvy_171819.csv', index=False)

# %%
df_all = pd.read_csv('/content/drive/MyDrive/DA ASSIGNMENT/DATA/divvy_171819.csv',parse_dates=['start_time', 'end_time'])
# Out:
# <ipython-input-2-4be18535920a>:1: DtypeWarning: Columns (4,6,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all = pd.read_csv('/content/drive/MyDrive/DA ASSIGNMENT/DATA/divvy_171819.csv',parse_dates=['start_time', 'end_time'])

# %%
df_all.dtypes
# Out:
# trip_id                     float64
# start_time           datetime64[ns]
# end_time             datetime64[ns]
# bikeid                      float64
# tripduration                 object
# from_station_id             float64
# from_station_name            object
# to_station_id               float64
# to_station_name              object
# usertype                     object
# gender                       object
# birthyear                   float64
# Quarter                      object
# dtype: object

# %%
df_all.head()
# Out:
#       trip_id          start_time            end_time  bikeid tripduration  \
# 0  13518905.0 2017-03-31 23:59:07 2017-04-01 00:13:24  5292.0          857
# 1  13518904.0 2017-03-31 23:56:25 2017-04-01 00:00:21  4408.0          236
# 2  13518903.0 2017-03-31 23:55:33 2017-04-01 00:01:21   696.0          348
# 3  13518902.0 2017-03-31 23:54:46 2017-03-31 23:59:34  4915.0          288
# 4  13518901.0 2017-03-31 23:53:33 2017-04-01 00:00:28  4247.0          415
#
#    from_station_id            from_station_name  to_station_id  \
# 0             66.0         Clinton St & Lake St          171.0
# 1            199.0       Wabash Ave & Grand Ave           26.0
# 2            520.0   Greenview Ave & Jarvis Ave          432.0
# 3            110.0        Dearborn St & Erie St          142.0
# 4            327.0  Sheffield Ave & Webster Ave          331.0
#
#                  to_station_name    usertype  gender  birthyear Quarter
# 0          May St & Cullerton St  Subscriber    Male     1989.0      Q1
# 1       McClurg Ct & Illinois St  Subscriber    Male     1990.0      Q1
# 2            Clark St & Lunt Ave  Subscriber  Female     1979.0      Q1
# 3           McClurg Ct & Erie St  Subscriber    Male     1985.0      Q1
# 4  Halsted St & Blackhawk St (*)  Subscriber  Female     1989.0      Q1

# %%
station_counts_from = pd.DataFrame(df_all['from_station_id'].value_counts())

# %%
station_counts_from.head()
# Out:
#        from_station_id
# 35.0            210661
# 192.0           144537
# 77.0            126130
# 91.0            125199
# 76.0            121461

# %%
station_counts_to= pd.DataFrame(df_all['to_station_id'].value_counts())

# %%
station_counts_to.head()
# Out:
#        to_station_id
# 35.0          238023
# 192.0         139113
# 77.0          126714
# 91.0          124373
# 268.0         119158

# %%
station_count = pd.concat([station_counts_from, station_counts_to], axis=1)
station_count.rename(columns={'from_station_id':'checkouts', 'to_station_id':'checkins'}, inplace=True)
station_count['total'] = station_count['checkouts'] + station_count['checkins']

# %%
station_count.head()
# Out:
#        checkouts  checkins   total
# 35.0      210661    238023  448684
# 192.0     144537    139113  283650
# 77.0      126130    126714  252844
# 91.0      125199    124373  249572
# 76.0      121461    106229  227690

# %%
station_count_26 = station_count.sort_values('total', ascending=False).head(26)
stations = list(station_count_26.index)

# %%
station = df_all[(df_all['from_station_id'].isin(stations)) | (df_all['to_station_id'].isin(stations))]

# %%
station.head()
# Out:
#       trip_id          start_time            end_time  bikeid tripduration  \
# 0  13518905.0 2017-03-31 23:59:07 2017-04-01 00:13:24  5292.0          857
# 1  13518904.0 2017-03-31 23:56:25 2017-04-01 00:00:21  4408.0          236
# 3  13518902.0 2017-03-31 23:54:46 2017-03-31 23:59:34  4915.0          288
# 6  13518899.0 2017-03-31 23:51:16 2017-03-31 23:57:17  5111.0          361
# 7  13518898.0 2017-03-31 23:50:26 2017-03-31 23:56:20  1579.0          354
#
#    from_station_id          from_station_name  to_station_id  \
# 0             66.0       Clinton St & Lake St          171.0
# 1            199.0     Wabash Ave & Grand Ave           26.0
# 3            110.0      Dearborn St & Erie St          142.0
# 6             81.0         Daley Center Plaza           41.0
# 7             56.0  Desplaines St & Kinzie St           77.0
#
#             to_station_name    usertype gender  birthyear Quarter
# 0     May St & Cullerton St  Subscriber   Male     1989.0      Q1
# 1  McClurg Ct & Illinois St  Subscriber   Male     1990.0      Q1
# 3      McClurg Ct & Erie St  Subscriber   Male     1985.0      Q1
# 6      Federal St & Polk St  Subscriber   Male     1987.0      Q1
# 7   Clinton St & Madison St  Subscriber   Male     1981.0      Q1

# %%
total_trip_count = df_all['trip_id'].count()
top_count = station['trip_id'].count()
percent = round(top_count/total_trip_count, 3) * 100

print("Of the {} total trips, {} involve one of our 26 stations. That's {}%".format(total_trip_count, top_count, percent))
# Out:
# Of the 9754792 total trips, 3772089 involve one of our 26 stations. That's 38.7%

# %%
station['start_time'] = pd.to_datetime(station['start_time'])
# Out:
# <ipython-input-15-b27ecc776bad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station['start_time'] = pd.to_datetime(station['start_time'])

# %%
model = station[['start_time', 'end_time', 'from_station_id', 'to_station_id']]

# %%
model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3772089 entries, 0 to 11250098
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   start_time       datetime64[ns]
#  1   end_time         datetime64[ns]
#  2   from_station_id  float64
#  3   to_station_id    float64
# dtypes: datetime64[ns](2), float64(2)
# memory usage: 143.9 MB

# %%
model.head(5)
# Out:
#            start_time            end_time  from_station_id  to_station_id
# 0 2017-03-31 23:59:07 2017-04-01 00:13:24             66.0          171.0
# 1 2017-03-31 23:56:25 2017-04-01 00:00:21            199.0           26.0
# 3 2017-03-31 23:54:46 2017-03-31 23:59:34            110.0          142.0
# 6 2017-03-31 23:51:16 2017-03-31 23:57:17             81.0           41.0
# 7 2017-03-31 23:50:26 2017-03-31 23:56:20             56.0           77.0

# %%
model['start_time'] = pd.to_datetime(model['start_time'])
# Out:
# <ipython-input-19-ea6953fb5595>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model['start_time'] = pd.to_datetime(model['start_time'])

# %%
model.index = model['start_time']
model.drop('start_time', axis=1, inplace=True)
# Out:
# <ipython-input-20-184baa3a8d67>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model.drop('start_time', axis=1, inplace=True)

# %%
model['day'] = model.index.day_name()
# Out:
# <ipython-input-21-3401f5784eda>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model['day'] = model.index.day_name()

# %%
model['year'] = model.index.map(lambda x:str(x)[:4])
model['hour'] = model.index.map(lambda x:str(x)[11:13])
# Out:
# <ipython-input-22-7770a39187f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model['year'] = model.index.map(lambda x:str(x)[:4])
# <ipython-input-22-7770a39187f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model['hour'] = model.index.map(lambda x:str(x)[11:13])

# %%
model.head()
# Out:
#                                end_time  from_station_id  to_station_id  \
# start_time
# 2017-03-31 23:59:07 2017-04-01 00:13:24             66.0          171.0
# 2017-03-31 23:56:25 2017-04-01 00:00:21            199.0           26.0
# 2017-03-31 23:54:46 2017-03-31 23:59:34            110.0          142.0
# 2017-03-31 23:51:16 2017-03-31 23:57:17             81.0           41.0
# 2017-03-31 23:50:26 2017-03-31 23:56:20             56.0           77.0
#
#                         day  year hour
# start_time
# 2017-03-31 23:59:07  Friday  2017   23
# 2017-03-31 23:56:25  Friday  2017   23
# 2017-03-31 23:54:46  Friday  2017   23
# 2017-03-31 23:51:16  Friday  2017   23
# 2017-03-31 23:50:26  Friday  2017   23

# %%
model_from_count = pd.DataFrame(model.groupby(['from_station_id', 'day', 'hour'])['year'].count())

# %%
model_from_count.reset_index()
# Out:
#        from_station_id        day hour  year
# 0                  2.0     Friday   00     7
# 1                  2.0     Friday   01    10
# 2                  2.0     Friday   04     2
# 3                  2.0     Friday   05     9
# 4                  2.0     Friday   06     7
# ...                ...        ...  ...   ...
# 49073            673.0  Wednesday   17    11
# 49074            673.0  Wednesday   18     2
# 49075            673.0  Wednesday   19     3
# 49076            673.0  Wednesday   20     1
# 49077            673.0  Wednesday   21     2
#
# [49078 rows x 4 columns]

# %%
checkouts = model[model['from_station_id'].isin(stations)]

# %%
checkouts.head(10)
# Out:
#                                end_time  from_station_id  to_station_id  \
# start_time
# 2017-03-31 23:59:07 2017-04-01 00:13:24             66.0          171.0
# 2017-03-31 23:54:46 2017-03-31 23:59:34            110.0          142.0
# 2017-03-31 23:51:16 2017-03-31 23:57:17             81.0           41.0
# 2017-03-31 23:45:21 2017-03-31 23:52:48             77.0          175.0
# 2017-03-31 23:45:00 2017-03-31 23:50:29             90.0            2.0
# 2017-03-31 23:43:24 2017-03-31 23:58:07             91.0          182.0
# 2017-03-31 23:35:20 2017-03-31 23:37:28             66.0          164.0
# 2017-03-31 23:34:57 2017-04-01 00:02:10             26.0          202.0
# 2017-03-31 23:15:12 2017-03-31 23:26:47             26.0          321.0
# 2017-03-31 23:11:19 2017-03-31 23:13:29             43.0           81.0
#
#                         day  year hour
# start_time
# 2017-03-31 23:59:07  Friday  2017   23
# 2017-03-31 23:54:46  Friday  2017   23
# 2017-03-31 23:51:16  Friday  2017   23
# 2017-03-31 23:45:21  Friday  2017   23
# 2017-03-31 23:45:00  Friday  2017   23
# 2017-03-31 23:43:24  Friday  2017   23
# 2017-03-31 23:35:20  Friday  2017   23
# 2017-03-31 23:34:57  Friday  2017   23
# 2017-03-31 23:15:12  Friday  2017   23
# 2017-03-31 23:11:19  Friday  2017   23

# %%
checkouts['month'] = checkouts.index.map(lambda x:str(x)[5:7])
# Out:
# <ipython-input-28-6ee7aa2209f9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checkouts['month'] = checkouts.index.map(lambda x:str(x)[5:7])

# %%
checkouts['groupby_col'] = checkouts.index.map(lambda x:str(x)[:13])
# Out:
# <ipython-input-29-8bedae24ae32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checkouts['groupby_col'] = checkouts.index.map(lambda x:str(x)[:13])

# %%
checkouts.head()
# Out:
#                                end_time  from_station_id  to_station_id  \
# start_time
# 2017-03-31 23:59:07 2017-04-01 00:13:24             66.0          171.0
# 2017-03-31 23:54:46 2017-03-31 23:59:34            110.0          142.0
# 2017-03-31 23:51:16 2017-03-31 23:57:17             81.0           41.0
# 2017-03-31 23:45:21 2017-03-31 23:52:48             77.0          175.0
# 2017-03-31 23:45:00 2017-03-31 23:50:29             90.0            2.0
#
#                         day  year hour month    groupby_col
# start_time
# 2017-03-31 23:59:07  Friday  2017   23    03  2017-03-31 23
# 2017-03-31 23:54:46  Friday  2017   23    03  2017-03-31 23
# 2017-03-31 23:51:16  Friday  2017   23    03  2017-03-31 23
# 2017-03-31 23:45:21  Friday  2017   23    03  2017-03-31 23
# 2017-03-31 23:45:00  Friday  2017   23    03  2017-03-31 23

# %%
checkouts_model = pd.DataFrame(checkouts.groupby(['from_station_id', 'groupby_col'])['hour'].count())

# %%
checkouts_model.rename(columns={'hour':'checkout_count'}, inplace=True)
checkouts_model.reset_index(inplace=True)
checkouts_model.index = checkouts_model['groupby_col']

# %%
checkouts_model.head()
# Out:
#                from_station_id    groupby_col  checkout_count
# groupby_col
# 2017-01-01 11              3.0  2017-01-01 11               2
# 2017-01-01 13              3.0  2017-01-01 13               3
# 2017-01-01 14              3.0  2017-01-01 14               2
# 2017-01-01 15              3.0  2017-01-01 15               4
# 2017-01-01 16              3.0  2017-01-01 16               2

# %%
checkouts_model['year'] = checkouts_model.index.map(lambda x:str(x)[:4])
checkouts_model['month'] = checkouts_model.index.map(lambda x:str(x)[5:7])
checkouts_model['hour'] = checkouts_model.index.map(lambda x:str(x)[11:13])

# %%
checkouts_model.head()
# Out:
#                from_station_id    groupby_col  checkout_count  year month hour
# groupby_col
# 2017-01-01 11              3.0  2017-01-01 11               2  2017    01   11
# 2017-01-01 13              3.0  2017-01-01 13               3  2017    01   13
# 2017-01-01 14              3.0  2017-01-01 14               2  2017    01   14
# 2017-01-01 15              3.0  2017-01-01 15               4  2017    01   15
# 2017-01-01 16              3.0  2017-01-01 16               2  2017    01   16

# %%
checkouts_model['groupby_col'] = pd.to_datetime(checkouts_model['groupby_col'])
checkouts_model.index = checkouts_model['groupby_col']

# %%
checkouts_model.head()
# Out:
#                      from_station_id         groupby_col  checkout_count  \
# groupby_col
# 2017-01-01 11:00:00              3.0 2017-01-01 11:00:00               2
# 2017-01-01 13:00:00              3.0 2017-01-01 13:00:00               3
# 2017-01-01 14:00:00              3.0 2017-01-01 14:00:00               2
# 2017-01-01 15:00:00              3.0 2017-01-01 15:00:00               4
# 2017-01-01 16:00:00              3.0 2017-01-01 16:00:00               2
#
#                      year month hour
# groupby_col
# 2017-01-01 11:00:00  2017    01   11
# 2017-01-01 13:00:00  2017    01   13
# 2017-01-01 14:00:00  2017    01   14
# 2017-01-01 15:00:00  2017    01   15
# 2017-01-01 16:00:00  2017    01   16

# %%
checkouts_model['day'] = checkouts_model.index.day_name()

# %%
checkouts_model.head()
# Out:
#                      from_station_id         groupby_col  checkout_count  \
# groupby_col
# 2017-01-01 11:00:00              3.0 2017-01-01 11:00:00               2
# 2017-01-01 13:00:00              3.0 2017-01-01 13:00:00               3
# 2017-01-01 14:00:00              3.0 2017-01-01 14:00:00               2
# 2017-01-01 15:00:00              3.0 2017-01-01 15:00:00               4
# 2017-01-01 16:00:00              3.0 2017-01-01 16:00:00               2
#
#                      year month hour     day
# groupby_col
# 2017-01-01 11:00:00  2017    01   11  Sunday
# 2017-01-01 13:00:00  2017    01   13  Sunday
# 2017-01-01 14:00:00  2017    01   14  Sunday
# 2017-01-01 15:00:00  2017    01   15  Sunday
# 2017-01-01 16:00:00  2017    01   16  Sunday

# %%
checkouts_model.drop('groupby_col', axis=1, inplace=True)

# %%
cols = checkouts_model.columns.tolist()

# %%
new_cols = ['checkout_count','from_station_id','year','month','hour','day']

# %%
checkouts_model = checkouts_model[new_cols]

# %%
checkouts_model.head()
# Out:
#                      checkout_count  from_station_id  year month hour     day
# groupby_col
# 2017-01-01 11:00:00               2              3.0  2017    01   11  Sunday
# 2017-01-01 13:00:00               3              3.0  2017    01   13  Sunday
# 2017-01-01 14:00:00               2              3.0  2017    01   14  Sunday
# 2017-01-01 15:00:00               4              3.0  2017    01   15  Sunday
# 2017-01-01 16:00:00               2              3.0  2017    01   16  Sunday

# %%
checkouts_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 323355 entries, 2017-01-01 11:00:00 to 2019-12-31 18:00:00
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   checkout_count   323355 non-null  int64
#  1   from_station_id  323355 non-null  float64
#  2   year             323355 non-null  object
#  3   month            323355 non-null  object
#  4   hour             323355 non-null  object
#  5   day              323355 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 17.3+ MB

# %%
checkouts_model['from_station_id'] = checkouts_model['from_station_id'].apply(str)

# %%
checkouts = pd.get_dummies(data=checkouts_model, columns=['from_station_id', 'year', 'month', 'day', 'hour'])

# %%
checkouts.head()
# Out:
#                      checkout_count  from_station_id_100.0  \
# groupby_col
# 2017-01-01 11:00:00               2                      0
# 2017-01-01 13:00:00               3                      0
# 2017-01-01 14:00:00               2                      0
# 2017-01-01 15:00:00               4                      0
# 2017-01-01 16:00:00               2                      0
#
#                      from_station_id_110.0  from_station_id_133.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
# 2017-01-01 14:00:00                      0                      0
# 2017-01-01 15:00:00                      0                      0
# 2017-01-01 16:00:00                      0                      0
#
#                      from_station_id_174.0  from_station_id_176.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
# 2017-01-01 14:00:00                      0                      0
# 2017-01-01 15:00:00                      0                      0
# 2017-01-01 16:00:00                      0                      0
#
#                      from_station_id_177.0  from_station_id_181.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
# 2017-01-01 14:00:00                      0                      0
# 2017-01-01 15:00:00                      0                      0
# 2017-01-01 16:00:00                      0                      0
#
#                      from_station_id_192.0  from_station_id_195.0  ...  \
# groupby_col                                                        ...
# 2017-01-01 11:00:00                      0                      0  ...
# 2017-01-01 13:00:00                      0                      0  ...
# 2017-01-01 14:00:00                      0                      0  ...
# 2017-01-01 15:00:00                      0                      0  ...
# 2017-01-01 16:00:00                      0                      0  ...
#
#                      hour_14  hour_15  hour_16  hour_17  hour_18  hour_19  \
# groupby_col
# 2017-01-01 11:00:00        0        0        0        0        0        0
# 2017-01-01 13:00:00        0        0        0        0        0        0
# 2017-01-01 14:00:00        1        0        0        0        0        0
# 2017-01-01 15:00:00        0        1        0        0        0        0
# 2017-01-01 16:00:00        0        0        1        0        0        0
#
#                      hour_20  hour_21  hour_22  hour_23
# groupby_col
# 2017-01-01 11:00:00        0        0        0        0
# 2017-01-01 13:00:00        0        0        0        0
# 2017-01-01 14:00:00        0        0        0        0
# 2017-01-01 15:00:00        0        0        0        0
# 2017-01-01 16:00:00        0        0        0        0
#
# [5 rows x 73 columns]

# %%
checkouts.shape
# Out:
# (323355, 73)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
plt.hist(checkouts['checkout_count'])
plt.show()

# %%
checkouts['checkout_count'].skew()
# Out:
# 3.9269471480506226

# %% [markdown]
# A skew of 0 is a normally distributed, a skew of 3.614 means the data is right skewed.

# %%
log_trans = np.log(checkouts['checkout_count']).skew()
sqrt_trans = (checkouts['checkout_count'] ** .5).skew()
cube_trans = (checkouts['checkout_count'] ** (1/3)).skew()

print('Log Transformation:', log_trans)
print('Square Root Transformation:', sqrt_trans)
print('Cube Root Transformation', cube_trans)
# Out:
# Log Transformation: 0.46488243035141413
# Square Root Transformation: 1.8057442045005339
# Cube Root Transformation 1.281213249113736

# %% [markdown]
# Our goal is to get the skew as close to 0 as possible, therefore the check-out column will be transformed using a log transformation.

# %%
checkouts['checkout_count(log)'] = np.log(checkouts['checkout_count'])

# %%
checkouts.head(3)
# Out:
#                      checkout_count  from_station_id_100.0  \
# groupby_col
# 2017-01-01 11:00:00               2                      0
# 2017-01-01 13:00:00               3                      0
# 2017-01-01 14:00:00               2                      0
#
#                      from_station_id_110.0  from_station_id_133.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
# 2017-01-01 14:00:00                      0                      0
#
#                      from_station_id_174.0  from_station_id_176.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
# 2017-01-01 14:00:00                      0                      0
#
#                      from_station_id_177.0  from_station_id_181.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
# 2017-01-01 14:00:00                      0                      0
#
#                      from_station_id_192.0  from_station_id_195.0  ...  \
# groupby_col                                                        ...
# 2017-01-01 11:00:00                      0                      0  ...
# 2017-01-01 13:00:00                      0                      0  ...
# 2017-01-01 14:00:00                      0                      0  ...
#
#                      hour_15  hour_16  hour_17  hour_18  hour_19  hour_20  \
# groupby_col
# 2017-01-01 11:00:00        0        0        0        0        0        0
# 2017-01-01 13:00:00        0        0        0        0        0        0
# 2017-01-01 14:00:00        0        0        0        0        0        0
#
#                      hour_21  hour_22  hour_23  checkout_count(log)
# groupby_col
# 2017-01-01 11:00:00        0        0        0             0.693147
# 2017-01-01 13:00:00        0        0        0             1.098612
# 2017-01-01 14:00:00        0        0        0             0.693147
#
# [3 rows x 74 columns]

# %%
checkouts.dtypes
# Out:
# checkout_count             int64
# from_station_id_100.0      uint8
# from_station_id_110.0      uint8
# from_station_id_133.0      uint8
# from_station_id_174.0      uint8
#                           ...
# hour_20                    uint8
# hour_21                    uint8
# hour_22                    uint8
# hour_23                    uint8
# checkout_count(log)      float64
# Length: 74, dtype: object

# %%
training = checkouts[:100831]
testing = checkouts[100831:]

# %%
y_train = training['checkout_count(log)']
x_train = training.drop(['checkout_count', 'checkout_count(log)'], axis=1)

y_test = testing['checkout_count(log)']
x_test = testing.drop(['checkout_count', 'checkout_count(log)'], axis=1)

# %%
x_train.shape
# Out:
# (100831, 72)

# %%
y_test.shape
# Out:
# (222524,)

# %%
from scipy import stats
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# DECISION TREE

# %%
dt = DecisionTreeRegressor()
regr_1 = DecisionTreeRegressor(max_depth=31)
regr_1.fit(x_train, y_train)
dt_pred1 = regr_1.predict(x_test)

# %%
# Mean Squared Error
dt1_mse = mean_squared_error(np.e ** y_test, np.e ** dt_pred1)
# r2 score
dt1_r2 = r2_score(np.e ** y_test, np.e ** dt_pred1)
# Mean Absolute Error
mean_ae = mean_absolute_error(np.e ** y_test, np.e ** dt_pred1)
# Median Absolute Error
median_ae = median_absolute_error(np.e ** y_test, np.e ** dt_pred1)

# %%
print('Mean Squared Error =', dt1_mse)
print('r2 =', dt1_r2)
print('Mean Absolute Error =', mean_ae)
print('Median Absolute Error =', median_ae)
# Out:
# Mean Squared Error = 77.93573760508369
# r2 = 0.18929804152689478
# Mean Absolute Error = 4.427952847413481
# Median Absolute Error = 1.8844991406148166

# %% [markdown]
# RANDOM FOREST REGRESSOR

# %%
rf = RandomForestRegressor(n_estimators=15)
rf.fit(x_train, y_train)
rf_preds = rf.predict(x_test)

# %%
# Mean Squared Error
rf_mse = mean_squared_error(np.e ** y_test, np.e ** rf_preds)
# r2 score
rf_r2 = r2_score(np.e ** y_test, np.e ** rf_preds)
# Mean Absolute Error
rf_mean_ae = mean_absolute_error(np.e ** y_test, np.e ** rf_preds)
# Median Absolute Error
rf_median_ae = median_absolute_error(np.e ** y_test, np.e ** rf_preds)

# %%
print('Mean Squared Error =', rf_mse)
print('r2 =', rf_r2)
print('Mean Absolute Error =', rf_mean_ae)
print('Median Absolute Error =', rf_median_ae)
# Out:
# Mean Squared Error = 78.82543113323803
# r2 = 0.18004328487891874
# Mean Absolute Error = 4.248923165151455
# Median Absolute Error = 1.7369791060632451

# %% [markdown]
# RIDGE REGRESSION

# %%
ridgeReg = Ridge(alpha=.00001)
ridgeReg.fit(x_train, y_train)
ridge_preds = ridgeReg.predict(x_test)

# %%
# Mean Squared Error
ridge_mse = mean_squared_error(np.e ** y_test, np.e ** ridge_preds)
# r2 score
ridge_r2 = r2_score(np.e ** y_test, np.e ** ridge_preds)
# Mean Absolute Error
ridge_mean_ae = mean_absolute_error(np.e ** y_test, np.e ** ridge_preds)
# Median Absolute Error
ridge_median_ae = median_absolute_error(np.e ** y_test, np.e ** ridge_preds)

# %%
print('Mean Squared Error =', ridge_mse)
print('r2 =', ridge_r2)
print('Mean Absolute Error =', ridge_mean_ae)
print('Median Absolute Error =', ridge_median_ae)
# Out:
# Mean Squared Error = 81.76502911074951
# r2 = 0.1494650429744412
# Mean Absolute Error = 4.356720430114666
# Median Absolute Error = 1.9404879645147144

# %% [markdown]
# LASSO REGRESSION

# %%
lasso = Lasso(alpha = .00005)
lasso.fit(x_train, y_train)
lasso_predictions = lasso.predict(x_test)

# %%
# Mean Squared Error
lasso_mse = mean_squared_error(np.e ** y_test, np.e ** lasso_predictions)
# r2 score
lasso_r2 = r2_score(np.e ** y_test, np.e ** lasso_predictions)
# Mean Absolute Error
lasso_mean_ae = mean_absolute_error(np.e ** y_test, np.e ** lasso_predictions)
# Median Absolute Error
lasso_median_ae = median_absolute_error(np.e ** y_test, np.e ** lasso_predictions)

# %%
print('Mean Squared Error =', lasso_mse)
print('r2 =', lasso_r2)
print('Mean Absolute Error =', lasso_mean_ae)
print('Median Absolute Error =', lasso_median_ae)
# Out:
# Mean Squared Error = 83.9878014691739
# r2 = 0.126343353752153
# Mean Absolute Error = 4.360304747768874
# Median Absolute Error = 1.8511290011665316

# %%
from plotly.tools import FigureFactory as FF
import plotly.offline as pyo

# %%
table_data = [['', 'Lasso Regression', 'Ridge Regression', 'Decision Tree', 'Random Forest'],
             ['Mean Square <br> Error',  round(lasso_mse, 4), round(ridge_mse, 4), round(dt1_mse, 4), round(rf_mse,4)],
             ['R2 Score',  round(lasso_r2, 4), round(ridge_r2, 4), round(dt1_r2, 4), round(rf_r2, 4)],
             ['Mean Absolute <br> Error',  round(lasso_mean_ae, 4), round(ridge_mean_ae, 4), round(mean_ae, 4), round(rf_mean_ae, 4)],
             ['Median Absolute <br> Error',  round(lasso_median_ae, 4), round(ridge_median_ae, 4), round(median_ae, 4), round(rf_median_ae, 4)]]

results_table = FF.create_table(table_data, index=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/tools.py:589: UserWarning:
#
# plotly.tools.FigureFactory.create_table is deprecated. Use plotly.figure_factory.create_table

# %%
results_table['data'][0]['colorscale'] = [[0, '#2d5986'], [0.5, '#d9e6f2'], [1, '#ffffff']]
pyo.iplot(results_table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7ef33a43-f835-44cb-9d9e-ae90b1d8d7e8" class="plotly-graph-div" style="height:200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ef33a43-f835-44cb-9d9e-ae90b1d8d7e8")) {                    Plotly.newPlot(                        "7ef33a43-f835-44cb-9d9e-ae90b1d8d7e8",                        [{"colorscale":[[0,"#2d5986"],[0.5,"#d9e6f2"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0,0,0],[0,0.5,0.5,0.5,0.5],[0,1,1,1,1],[0,0.5,0.5,0.5,0.5],[0,1,1,1,1]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003e\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eLasso Regression\u003c\u002fb\u003e","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eRidge Regression\u003c\u002fb\u003e","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eDecision Tree\u003c\u002fb\u003e","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eRandom Forest\u003c\u002fb\u003e","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMean Square \u003cbr\u003e Error\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"83.9878","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"81.765","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"77.9357","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"78.8254","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eR2 Score\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1263","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1495","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1893","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.18","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMean Absolute \u003cbr\u003e Error\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"4.3603","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"4.3567","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"4.428","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"4.2489","x":3.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMedian Absolute \u003cbr\u003e Error\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"al ...

# %%
all_test = checkouts_model[100831:]

# %%
all_test.head(3)
# Out:
#                      checkout_count from_station_id  year month hour       day
# groupby_col
# 2017-06-10 14:00:00               4            81.0  2017    06   14  Saturday
# 2017-06-10 15:00:00               4            81.0  2017    06   15  Saturday
# 2017-06-10 16:00:00               2            81.0  2017    06   16  Saturday

# %%
all_test['Predictions'] = np.e ** rf_preds

# %%
all_test['Difference'] = all_test['Predictions'] - all_test['checkout_count']

# %%
all_test['date'] = all_test.index

# %%
all_test['text'] = all_test.apply(lambda x: 'Predicted Difference: ' + str(round(x['Difference'], 2)) + '<br> Date: '
                                            + str(x['date']) + '<br> Station:' + x['from_station_id'], axis=1)

# %%
all_test.head(3)
# Out:
#                      checkout_count from_station_id  year month hour  \
# groupby_col
# 2017-06-10 14:00:00               4            81.0  2017    06   14
# 2017-06-10 15:00:00               4            81.0  2017    06   15
# 2017-06-10 16:00:00               2            81.0  2017    06   16
#
#                           day  Predictions  Difference                date  \
# groupby_col
# 2017-06-10 14:00:00  Saturday     2.625336   -1.374664 2017-06-10 14:00:00
# 2017-06-10 15:00:00  Saturday     4.010200    0.010200 2017-06-10 15:00:00
# 2017-06-10 16:00:00  Saturday     3.227969    1.227969 2017-06-10 16:00:00
#
#                                                                   text
# groupby_col
# 2017-06-10 14:00:00  Predicted Difference: -1.37<br> Date: 2017-06-...
# 2017-06-10 15:00:00  Predicted Difference: 0.01<br> Date: 2017-06-1...
# 2017-06-10 16:00:00  Predicted Difference: 1.23<br> Date: 2017-06-1...

# %%
under5 = all_test[abs(all_test['Difference']) <= 5]['Difference'].count()
total = all_test['Difference'].count()
perc = round((all_test[abs(all_test['Difference']) <= 5]['Difference'].count() / all_test['Difference'].count()) * 100, 2)

print('Of the {} trips, {} were predicted with in 5 bikes.  That is {}% of all instances'.format(total, under5, perc))
# Out:
# Of the 222524 trips, 174914 were predicted with in 5 bikes.  That is 78.6% of all instances

# %% [markdown]
# REMOVING OUTLINERS

# %%
checkouts.head(2)
# Out:
#                      checkout_count  from_station_id_100.0  \
# groupby_col
# 2017-01-01 11:00:00               2                      0
# 2017-01-01 13:00:00               3                      0
#
#                      from_station_id_110.0  from_station_id_133.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
#
#                      from_station_id_174.0  from_station_id_176.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
#
#                      from_station_id_177.0  from_station_id_181.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
#
#                      from_station_id_192.0  from_station_id_195.0  ...  \
# groupby_col                                                        ...
# 2017-01-01 11:00:00                      0                      0  ...
# 2017-01-01 13:00:00                      0                      0  ...
#
#                      hour_15  hour_16  hour_17  hour_18  hour_19  hour_20  \
# groupby_col
# 2017-01-01 11:00:00        0        0        0        0        0        0
# 2017-01-01 13:00:00        0        0        0        0        0        0
#
#                      hour_21  hour_22  hour_23  checkout_count(log)
# groupby_col
# 2017-01-01 11:00:00        0        0        0             0.693147
# 2017-01-01 13:00:00        0        0        0             1.098612
#
# [2 rows x 74 columns]

# %%
checkouts['z'] = np.abs(stats.zscore(checkouts['checkout_count']))

# %%
checkouts.head(2)
# Out:
#                      checkout_count  from_station_id_100.0  \
# groupby_col
# 2017-01-01 11:00:00               2                      0
# 2017-01-01 13:00:00               3                      0
#
#                      from_station_id_110.0  from_station_id_133.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
#
#                      from_station_id_174.0  from_station_id_176.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
#
#                      from_station_id_177.0  from_station_id_181.0  \
# groupby_col
# 2017-01-01 11:00:00                      0                      0
# 2017-01-01 13:00:00                      0                      0
#
#                      from_station_id_192.0  from_station_id_195.0  ...  \
# groupby_col                                                        ...
# 2017-01-01 11:00:00                      0                      0  ...
# 2017-01-01 13:00:00                      0                      0  ...
#
#                      hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  \
# groupby_col
# 2017-01-01 11:00:00        0        0        0        0        0        0
# 2017-01-01 13:00:00        0        0        0        0        0        0
#
#                      hour_22  hour_23  checkout_count(log)         z
# groupby_col
# 2017-01-01 11:00:00        0        0             0.693147  0.490296
# 2017-01-01 13:00:00        0        0             1.098612  0.396070
#
# [2 rows x 75 columns]

# %%
checkouts_o = checkouts[checkouts['z'] < 3]

# %%
print('There were',checkouts['z'].count() - checkouts_o['z'].count(), 'outliers removed from the data.')
# Out:
# There were 7415 outliers removed from the data.

# %%
training_o = checkouts_o[:98589]
testing_o = checkouts_o[98589:]

# %%
y_train_o = training_o['checkout_count(log)']
x_train_o = training_o.drop(['checkout_count', 'checkout_count(log)', 'z'], axis=1)

y_test_o = testing_o['checkout_count(log)']
x_test_o = testing_o.drop(['checkout_count', 'checkout_count(log)', 'z'], axis=1)

# %%
x_train_o.shape
# Out:
# (98589, 72)

# %%
rf_outliers = RandomForestRegressor(n_estimators=15)
rf_outliers.fit(x_train_o, y_train_o)
rf_outliers_pred = rf_outliers.predict(x_test_o)

# %%
# Mean Squared Error
rfo_mse = mean_squared_error(np.e ** y_test_o, np.e ** rf_outliers_pred)

# r2 score
rfo_r2 = r2_score(np.e ** y_test_o, np.e ** rf_outliers_pred)

# Mean Absolute Error
rfo_mean_ae = mean_absolute_error(np.e ** y_test_o, np.e ** rf_outliers_pred)

# Median Absolute Error
rfo_median_ae = median_absolute_error(np.e ** y_test_o, np.e ** rf_outliers_pred)

print('Mean Squared Error =', rfo_mse)
print('r2 =', rfo_r2)
print('Mean Absolute Error =', rfo_mean_ae)
print('Median Absolute Error =', rfo_median_ae)
# Out:
# Mean Squared Error = 35.607909154084865
# r2 = 0.19294021260494754
# Mean Absolute Error = 3.4559486286992116
# Median Absolute Error = 1.6718146419756748

# %%
dto = DecisionTreeRegressor(max_depth=31)
dto.fit(x_train_o, y_train_o)
dto_pred = dto.predict(x_test_o)

# %%
# Mean Squared Error
dto_mse = mean_squared_error(np.e ** y_test_o, np.e ** dto_pred)

# r2 score
dto_r2 = r2_score(np.e ** y_test_o, np.e ** dto_pred)

# Mean Absolute Error
dto_mean_ae = mean_absolute_error(np.e ** y_test_o, np.e ** dto_pred)

# Median Absolute Error
dto_median_ae = median_absolute_error(np.e ** y_test_o, np.e ** dto_pred)

print('Mean Squared Error =', dto_mse)
print('r2 =', dto_r2)
print('Mean Absolute Error =', dto_mean_ae)
print('Median Absolute Error =', dto_median_ae)
# Out:
# Mean Squared Error = 41.2862764763019
# r2 = 0.06423897648382115
# Mean Absolute Error = 3.7448621139622036
# Median Absolute Error = 1.8382085497121823

# %%
ridge_outlier = Ridge()
ridge_outlier.fit(x_train_o, y_train_o)
ro_pred = ridge_outlier.predict(x_test_o)

# %%
ro_mse = mean_squared_error(np.e ** y_test_o, np.e ** ro_pred)
ro_r2 = r2_score(np.e ** y_test_o, np.e ** ro_pred)
ro_mean_ae = mean_absolute_error(np.e ** y_test_o, np.e ** ro_pred)
ro_median_ae = median_absolute_error(np.e ** y_test_o, np.e ** ro_pred)

print('Mean Squared Error =', ro_mse)
print('r2 =', ro_r2)
print('Mean Absolute Error =', ro_mean_ae)
print('Median Absolute Error =', ro_median_ae)
# Out:
# Mean Squared Error = 36.82612255538628
# r2 = 0.16532918258345208
# Mean Absolute Error = 3.5187437671774378
# Median Absolute Error = 1.7989007014235832

# %%
## Lasso Regression with outliers removed

lasso_outlier = Lasso(alpha=.00005)
lasso_outlier.fit(x_train_o, y_train_o)
laso_pred = lasso_outlier.predict(x_test_o)

# %%
laso_mse = mean_squared_error(np.e ** y_test_o, np.e ** laso_pred)
laso_r2 = r2_score(np.e ** y_test_o, np.e ** laso_pred)
laso_mean_ae = mean_absolute_error(np.e ** y_test_o, np.e ** laso_pred)
laso_median_ae = median_absolute_error(np.e ** y_test_o, np.e ** laso_pred)

print('Mean Squared Error =', laso_mse)
print('r2 =', laso_r2)
print('Mean Absolute Error =', laso_mean_ae)
print('Median Absolute Error =', laso_median_ae)
# Out:
# Mean Squared Error = 37.20402229302082
# r2 = 0.15676401576637722
# Mean Absolute Error = 3.520883509113602
# Median Absolute Error = 1.7696884401656021

# %%
outlier_table_data = [['', 'Lasso Regression', 'Ridge Regression', 'Decision Tree', 'Random Forest'],
             ['Mean Square <br> Error', round(laso_mse, 4), round(ro_mse, 4), round(dto_mse, 4), round(rfo_mse,4)],
             ['R2 Score', round(laso_r2, 4), round(ro_r2, 4), round(dto_r2, 4), round(rfo_r2, 4)],
             ['Mean Absolute <br> Error', round(laso_mean_ae, 4), round(ro_mean_ae, 4), round(dto_mean_ae, 4), round(rfo_mean_ae, 4)],
             ['Median Absolute <br> Error', round(laso_median_ae, 4), round(ro_median_ae, 4), round(dto_median_ae, 4), round(rfo_median_ae, 4)]]

# %%
outliers_table = FF.create_table(outlier_table_data, index=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/tools.py:589: UserWarning:
#
# plotly.tools.FigureFactory.create_table is deprecated. Use plotly.figure_factory.create_table

# %%
testing_o['predictions'] = np.e ** rf_outliers_pred

# %%
testing_o.sort_values('predictions', ascending=False).head(2)
# Out:
#                      checkout_count  from_station_id_100.0  \
# groupby_col
# 2017-08-29 18:00:00              33                      0
# 2017-08-22 18:00:00              18                      0
#
#                      from_station_id_110.0  from_station_id_133.0  \
# groupby_col
# 2017-08-29 18:00:00                      0                      0
# 2017-08-22 18:00:00                      0                      0
#
#                      from_station_id_174.0  from_station_id_176.0  \
# groupby_col
# 2017-08-29 18:00:00                      0                      0
# 2017-08-22 18:00:00                      0                      0
#
#                      from_station_id_177.0  from_station_id_181.0  \
# groupby_col
# 2017-08-29 18:00:00                      0                      0
# 2017-08-22 18:00:00                      0                      0
#
#                      from_station_id_192.0  from_station_id_195.0  ...  \
# groupby_col                                                        ...
# 2017-08-29 18:00:00                      0                      0  ...
# 2017-08-22 18:00:00                      0                      0  ...
#
#                      hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  \
# groupby_col
# 2017-08-29 18:00:00        0        1        0        0        0        0
# 2017-08-22 18:00:00        0        1        0        0        0        0
#
#                      hour_23  checkout_count(log)         z  predictions
# groupby_col
# 2017-08-29 18:00:00        0             3.496508  2.430725    33.329204
# 2017-08-22 18:00:00        0             2.890372  1.017328    33.329204
#
# [2 rows x 76 columns]

# %%
## Revert back to the original dataframe used and add a column for z-scores

checkouts_model['z'] = np.abs(stats.zscore(checkouts_model['checkout_count']))

# %%
checkouts_model.head(2)
# Out:
#                      checkout_count from_station_id  year month hour     day  \
# groupby_col
# 2017-01-01 11:00:00               2             3.0  2017    01   11  Sunday
# 2017-01-01 13:00:00               3             3.0  2017    01   13  Sunday
#
#                             z
# groupby_col
# 2017-01-01 11:00:00  0.490296
# 2017-01-01 13:00:00  0.396070

# %%
checkouts_model.shape
# Out:
# (323355, 7)

# %%
## Create the testing set to run more models

checkouts_model_testing = checkouts_model[100831:]
checkouts_model_testing['Predictions'] = np.e ** rf_preds

# %%
checkouts_model_testing.head(2)
# Out:
#                      checkout_count from_station_id  year month hour  \
# groupby_col
# 2017-06-10 14:00:00               4            81.0  2017    06   14
# 2017-06-10 15:00:00               4            81.0  2017    06   15
#
#                           day         z  Predictions
# groupby_col
# 2017-06-10 14:00:00  Saturday  0.301843     2.625336
# 2017-06-10 15:00:00  Saturday  0.301843     4.010200

# %%
checkouts_model_testing['Difference'] = checkouts_model_testing['Predictions'] - checkouts_model_testing['checkout_count']

# %%
## Create the x and y sets from the dataset, dropping appropriate columns.

checkouts_rand_x = checkouts.drop(['checkout_count', 'checkout_count(log)', 'z'], axis=1)
checkouts_rand_y = checkouts['checkout_count(log)']

# %%
## Import the built-in train_test_split function from sklearn

from sklearn.model_selection import train_test_split

# %%
## test on a random sample
x_train_rand, x_test_rand, y_train_rand, y_test_rand = train_test_split(checkouts_rand_x, checkouts_rand_y, test_size=.25, random_state=42)

# %%
## Shape of the testing set

x_test_rand.shape
# Out:
# (80839, 72)

# %%
## Random Forest with random split

rf_rand = RandomForestRegressor(n_estimators=15)
rf_rand.fit(x_train_rand, y_train_rand)
rf_rand_pred = rf_rand.predict(x_test_rand)

# %%
# Mean Squared Error
rfrand_mse = mean_squared_error(np.e ** y_test_rand, np.e ** rf_rand_pred)

# r2 score
rfrand_r2 = r2_score(np.e ** y_test_rand, np.e ** rf_rand_pred)

# Mean Absolute Error
rfrand_mean_ae = mean_absolute_error(np.e ** y_test_rand, np.e ** rf_rand_pred)

# Median Absolute Error
rfrand_median_ae = median_absolute_error(np.e ** y_test_rand, np.e ** rf_rand_pred)

# %%
print('Mean Squared Error =', rfrand_mse)
print('r2 =', rfrand_r2)
print('Mean Absolute Error =', rfrand_mean_ae)
print('Median Absolute Error =', rfrand_median_ae)
# Out:
# Mean Squared Error = 40.239801795283775
# r2 = 0.637812917591752
# Mean Absolute Error = 3.3158337611442277
# Median Absolute Error = 1.6001128929455182

# %%
## Create the x and y sets, but with the outliers removed

checkouts_rand_x_wo = checkouts_o.drop(['checkout_count', 'checkout_count(log)', 'z'], axis=1)
checkouts_rand_y_wo = checkouts_o['checkout_count(log)']

# %%
## Randomly split the data using 25% for the testing set

x_train_randwo, x_test_randwo, y_train_randwo, y_test_randwo = train_test_split(checkouts_rand_x_wo, checkouts_rand_y_wo, test_size=.25, random_state=42)

# %%
x_test_randwo.shape
# Out:
# (78985, 72)

# %%
## Random Forest with random split and outliers removed

rf_randwo = RandomForestRegressor(n_estimators=15)
rf_randwo.fit(x_train_randwo, y_train_randwo)
rf_rand_predwo = rf_randwo.predict(x_test_randwo)

# %%
# Mean Squared Error
rfrandwo_mse = mean_squared_error(np.e ** y_test_randwo, np.e ** rf_rand_predwo)

# r2 score
rfrandwo_r2 = r2_score(np.e ** y_test_randwo, np.e ** rf_rand_predwo)

# Mean Absolute Error
rfrandwo_mean_ae = mean_absolute_error(np.e ** y_test_randwo, np.e ** rf_rand_predwo)

# Median Absolute Error
rfrandwo_median_ae = median_absolute_error(np.e ** y_test_randwo, np.e ** rf_rand_predwo)

print('Mean Squared Error =', rfrandwo_mse)
print('r2 =', rfrandwo_r2)
print('Mean Absolute Error =', rfrandwo_mean_ae)
print('Median Absolute Error =', rfrandwo_median_ae)
# Out:
# Mean Squared Error = 22.38835093329209
# r2 = 0.5286990335395251
# Mean Absolute Error = 2.863339982655955
# Median Absolute Error = 1.540609502771745

# %%
random_forest = [['', 'Last 2 Weeks', 'Last 2 Weeks <br> Outliers Removed', 'Random 25% Split', 'Random 25% Split <br> Outliers Removed'],
                ['Mean Squared Error', round(rf_mse, 4), round(rfo_mse, 4), round(rfrand_mse,4 ), round(rfrandwo_mse, 4)],
                ['R2 Score', round(rf_r2, 4), round(rfo_r2, 4), round(rfrand_r2, 4), round(rfrandwo_r2, 4)],
                ['Mean Absolute <br> Error', round(rf_mean_ae, 4), round(rfo_mean_ae, 4), round(rfrand_mean_ae, 4), round(rfrandwo_mean_ae, 4)],
                ['Median Absolute <br> Error', round(rf_median_ae, 4), round(rfo_median_ae, 4), round(rfrand_median_ae, 4), round(rfrandwo_median_ae, 4)]]

# %%
import plotly.figure_factory as ff
random_forest_table = ff.create_table(random_forest, index=True)

# %%
random_forest_table['data'][0]['colorscale'] = [[0, '#2d5986'], [0.5, '#d9e6f2'], [1, '#ffffff']]
pyo.iplot(random_forest_table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eaf08402-0021-4c88-b5d3-cd1dc52179b4" class="plotly-graph-div" style="height:200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaf08402-0021-4c88-b5d3-cd1dc52179b4")) {                    Plotly.newPlot(                        "eaf08402-0021-4c88-b5d3-cd1dc52179b4",                        [{"colorscale":[[0,"#2d5986"],[0.5,"#d9e6f2"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0,0,0],[0,0.5,0.5,0.5,0.5],[0,1,1,1,1],[0,0.5,0.5,0.5,0.5],[0,1,1,1,1]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003e\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eLast 2 Weeks\u003c\u002fb\u003e","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eLast 2 Weeks \u003cbr\u003e Outliers Removed\u003c\u002fb\u003e","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eRandom 25% Split\u003c\u002fb\u003e","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eRandom 25% Split \u003cbr\u003e Outliers Removed\u003c\u002fb\u003e","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMean Squared Error\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"78.8254","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"35.6079","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"40.2398","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"22.3884","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eR2 Score\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.18","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1929","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.6378","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5287","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMean Absolute \u003cbr\u003e Error\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"4.2489","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"3.4559","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"3.3158","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"2.8633","x":3.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMedian Absolute \u003cbr\u003e Error\u003c\u002fb\u003e","x":-0.45, ...

# %%
## Create a scatter plot (Predicted vs Actual) using the random split with the outliers.
## Hovertext is difference of predictions minus actual

random_trace = {'type' : 'scatter',
               'x' : np.e ** y_test_rand,
               'y' : np.e ** rf_rand_pred,
               'mode' : 'markers',
               'name' : 'Error Analysis (Random Split)',
               'text' : round(np.e ** rf_rand_pred - np.e ** y_test_rand, 4),
               'hoverinfo' : 'text',
               'marker' : {'opacity' : .6,
                          'line' : {'width' : 1,
                                   'color' : '#333'}}}

layout = {'title' : 'Error Analysis on Random Split Data',
         'xaxis' : {'title' : 'Actual Checkouts'},
         'yaxis' : {'title' : 'Predicted Checkouts'},
         'hovermode' : 'closest'}

random_split_analysis = {'data':[random_trace], 'layout':layout}

pyo.iplot(random_split_analysis)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ddac3137-9feb-4826-9beb-1e99077bb388" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddac3137-9feb-4826-9beb-1e99077bb388")) {                    Plotly.newPlot(                        "ddac3137-9feb-4826-9beb-1e99077bb388",                        [{"hoverinfo":"text","marker":{"line":{"color":"#333","width":1},"opacity":0.6},"mode":"markers","name":"Error Analysis (Random Split)","text":[0.7049,0.6822,0.3904,1.8249,-2.996,-2.8894,1.8947,2.0122,-0.4948,-2.619,0.6242,-0.0903,-0.5302,0.79,0.1452,0.797,-2.0844,4.4435,-3.3693,-0.912,-17.0585,0.9809,-24.1379,0.0093,-0.5709,-0.2572,-7.2002,-3.1124,4.9221,-1.0826,-2.0187,0.0935,1.5505,0.0248,0.4979,1.5419,0.202,-7.1783,2.4052,-4.9747,-1.9199,-1.1027,1.4829,-2.7007,0.6309,3.8019,0.7637,2.0064,0.0473,-5.3878,1.6804,0.8153,0.5329,2.5138,-2.2582,-0.3911,1.4929,-1.7689,-13.181,0.0,1.7047,-0.5336,-1.2621,-0.9171,-3.1122,-22.8399,-0.703,20.7807,1.5912,1.4441,10.3646,-5.3229,0.6338,0.9124,0.0,-0.1298,1.867,2.7269,1.1272,-2.255,-0.6774,-6.7103,-1.9599,-1.2894,-5.3608,-0.0998,0.0,-5.2357,-0.7294,-0.5263,-0.9687,-6.6514,-4.8563,-2.6251,-0.6059,17.7431,1.488,13.3091,0.4123,3.2693,2.6099,3.098,-7.6258,-1.2993,-2.8422,-0.7737,-15.3836,-0.0,-0.7524,-1.7642,2.8968,-3.3252,-30.9155,-0.1304,1.5471,-0.5431,-4.0482,-1.5402,0.792,-0.1706,-2.5775,0.7383,-3.5893,0.3795,-7.3648,0.4587,-1.0,2.9377,-2.5854,-3.1202,0.8948,0.5012,-0.2807,-2.0131,1.0074,13.728,-15.226,-0.6343,1.0226,0.2869,-0.6966,1.6748,-2.6892,0.8609,-0.3924,-0.9292,-0.951,1.0805,-1.9918,0.0473,-0.8074,-4.4473,0.2697,-1.472,1.8396,20.786,-3.2758,-1.9788,2.7051,-5.6853,8.0064,-1.6251,0.798,0.0473,-3.0109,3.0958,2.37,-11.3698,0.0,1.3137,-0.0903,-3.8625,-4.5751,10.9179,-10.4354,0.3288,4.8576,-22.6045,-2.1794,-0.5172,0.8535,1.2719,-8.2228,-9.8992,2.3414,1.5631,-1.069,-7.026,2.6021,0.0,0.7548,-7.3862,-0.9845,-5.8731,-3.0,-5.5125,-11.3962,-1.8821,0.4968,0.0,6.3733,0.4717,-0.7723,1.6742,-3.6418,-5.5421,3.4898,-0.1551,0.4991,0.0741,-2.16,-2.5313,0.1972,1.9478,2.7285,-1.5457,-3.963,-0.9158,1.0287,0.0,3.41,-1.5017,0.5157,0.829,-2.4636,0.3822,-0.391,0.2938,1.1698,0.6852,2.7033,-4.1868,3.1713,0.2816,-3.426,1.2456,0.7573,-4.8743,-14.4876,-1.2251,-2.7562,-0.8198,0.1182,0.4986,3.1158,-5.0508,-5.2274,0.9004,0.203,-1.8171,-2.9369,-7.8637,-0.4008,5.5652,0.2384,0.5597,-1.2157,0.8552,2.338,7.0687,0.0155,0.5099,0.2503,0.2344,1.7292,0.0,-3.6051,1.2908,-8.4026,12.0966,1.0807,-12.5435,1.3862,-1.781,2.448,0.3503,12.6979,0.6851,1.2541,0.5125,-0.276,1.6719,-1.0602,1.0516,3.5618,-8.3602,-0.6504,0.0,6.1997,-0.7949,-2.7379,0.0303,-1.7891,0.361,-8.4414,-12.9441,-9.5348,-2.1752,-0.9527,0.9877,0.3661,0.9765,1.7752,0.0334,-1.1489,0.6867,-2.0522,0.0319,2.537,3.0112,-5.5127,1.9364,-1.6276,0.2894,11.9081,1.521,-10.5986,1.1247,1.1419,1.3666,-4.0568,-0.3557,-47.1331,8.9825,2.2447,0.3766,-10.5798,-3.7472,-3.2136,-2.0579,-2.0,-7.2529,-2.6645,2.4256,-5.8363,0.0,0.7417,-8.9343,-1.8658,3.371,-1.9337,0.5009,0.0612,2.7221,-2.1419,0.236,-5.5638,-0.6667,0.9939,-2.9456,2.9514,15.5686,-0.4998,-24.2423,-2.4638,-13.0344,-3.9921,8.2993,3.6499,0.0,4.2955,3.5318,-0.1367,0.2613,-2.1702,0.8131,-2.5827,-1.6475,5.7913,-0.5492,-6.3374,3.5763,-1.0,-1.0692,0.246,0.5227,0.0554,-0.7241,0.7735,-2.7674,1.7782,0.6112,-6.7286,-12.6831,2.3749,0.0962,-17.5778,-0.797,-16.6427,2.289,2.5455,-0.1544,13.9213,0.5005,-0.2679,0.6816,0.0,1.7246,0.2245,-1.105,0.0155,-13.0585,1.1006,-1.7384,3.0556,-7.8662,6.8041,0.2664,-3.795,4.4903,-6.4655,-1.5836,2.6947,-0.3408,0.5798,-9.1544,-7.9488,12.5897,4.5393,-11.1317,-3.0199,1.5634,3.1964,0.9953,-4.7802,2.2688,0.7013,-3.1584,-3.9432,1.6442,0.6135,1.9886,2.1888,4.2388,0.0407,1.056,0.8734,1.2932,1.0111,-9.2678,-1.2882,6.3969,0.6561,-0.6492,-1.393,0.1487,-7.4842,2.8163,0.047 ...
